# %%
# Notebook snippet
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    print(f"[INFO] Added project root to sys.path: {project_root}")
else:
    print(f"[INFO] Project root already in sys.path: {project_root}")

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from src import stock_stat as stat

corr_matrix = stat.returns_df.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Return correlation matrix", fontsize=14)
plt.show()
# Out:
# [INFO] Project root already in sys.path: c:\Users\jakub\Desktop\QUANTWANNABE\portfolio-optimization-markowitz
